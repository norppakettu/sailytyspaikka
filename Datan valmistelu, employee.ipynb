# %%
import pandas as pd
df = pd.read_csv('http://taanila.fi/employee.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.count()
# Out:
# Age                         1470
# Attrition                   1470
# BusinessTravel              1470
# DailyRate                   1470
# Department                  1470
# DistanceFromHome            1470
# Education                   1470
# EducationField              1470
# EmployeeCount               1470
# EmployeeNumber              1470
# EnvironmentSatisfaction     1470
# Gender                      1470
# HourlyRate                  1470
# JobInvolvement              1470
# JobLevel                    1470
# JobRole                     1470
# JobSatisfaction             1470
# MaritalStatus               1470
# MonthlyIncome               1470
# MonthlyRate                 1470
# NumCompaniesWorked          1470
# Over18                      1470
# OverTime                    1470
# PercentSalaryHike           1470
# PerformanceRating           1470
# RelationshipSatisfaction    1470
# StandardHours               1470
# StockOptionLevel            1470
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
for var in df:
    print(var, pd.unique(df[var]))
# Out:
# Age [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# Attrition ['Yes' 'No']
# BusinessTravel ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# DailyRate [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
#   489  807  827  871  665 1040 1420  240 1280  534 1456  658  142 1127
#  1031 1189 1354 1467  922  394 1312  750  441  684  249  841  147  528
#   594  470  957  542  802 1355 1150 1329  959 1033 1316  364  438  689
# ...

# %%
df['Education_text'] = df['Education'].replace({1 : 'Below College', 
                                                2 : 'College',
                                                3 : 'Bachelor', 
                                                4 : 'Master', 
                                                5 : 'Doctor'})
df['JobInvolvement_text'] = df['JobInvolvement'].replace({ 1: 'Low',
                                                        2 : 'Medium',
                                                        3 : 'High',
                                                        4 : 'Very high'})
df['PerformanceRating_text'] = df['PerformanceRating'].replace({ 1: 'Low',
                                                              2 : 'Good',
                                                              3 : 'Excellent',
                                                              4 :'Outstanding'})
df['RelationshipSatisfaction_text'] = df['RelationshipSatisfaction'].replace({1 : 'Low', 
                                                                              2 : 'Medium',
                                                                              3 : 'High',
                                                                              4 :'Very high'})

df['WorkLifeBalance_text'] = df['WorkLifeBalance'].replace({1 : 'Bad',
                                                            2 : 'Good',
                                                            3 : 'Better', 
                                                            4 : 'Best'})
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# ...

# %%
bins = [250, 500, 750, 1000, 1250, 1500, 1750]
df['DailyRateClass'] = pd.cut(df['DailyRate'], bins = bins)

bins1 = [0, 5, 10, 15, 20, 25]
df['Distance Class'] = pd.cut(df['DistanceFromHome'], bins = bins1)

bins3 = [10, 20, 30, 40, 50, 60]
df['Age Class'] = pd.cut(df['Age'], bins = bins3)

df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  YearsSinceLastPromotion YearsWithCurrManager  Education_text  \
# ...

# %%
df['Overall Satisfaction'] = df[['EnvironmentSatisfaction', 
                                 'JobSatisfaction', 
                                 'RelationshipSatisfaction']].mean(axis=1)

df[['Age', 'YearsAtCompany', 'Overall Satisfaction']].head()
# Out:
#    Age  YearsAtCompany  Overall Satisfaction
# 0   41               6              2.333333
# 1   49              10              3.000000
# 2   37               0              3.000000
# 3   33               8              3.333333
# 4   27               2              2.333333

# %%
df[['Age', 'YearsAtCompany', 'Overall Satisfaction']].sort_values(by='Overall Satisfaction').head()
# Out:
#      Age  YearsAtCompany  Overall Satisfaction
# 516   23               3                   1.0
# 829   33               5                   1.0
# 864   41               1                   1.0
# 140   32               5                   1.0
# 619   33               9                   1.0

# %%
df[['Age', 'YearsAtCompany', 'Overall Satisfaction']].sort_values(by='Overall Satisfaction', ascending=False).head()
# Out:
#       Age  YearsAtCompany  Overall Satisfaction
# 58     31               7                   4.0
# 218    45              19                   4.0
# 408    52               5                   4.0
# 1187   38              13                   4.0
# 1092   45               5                   4.0

# %%
df.drop(['Age', 'BusinessTravel', 'DailyRate', 'DistanceFromHome', 
         'EducationField', 'EmployeeCount', 'EmployeeNumber', 
         'EnvironmentSatisfaction', 'MaritalStatus', 'HourlyRate',
         'JobRole', 'JobSatisfaction', 'MonthlyRate', 
         'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 
         'StockOptionLevel', 'StandardHours', 'TotalWorkingYears',
         'YearsWithCurrManager', 'Education', 'JobInvolvement', 
         'PerformanceRating', 'RelationshipSatisfaction', 'WorkLifeBalance'],
        axis=1).head()
# Out:
#   Attrition              Department  Gender  JobLevel  MonthlyIncome OverTime  \
# 0       Yes                   Sales  Female         2           5993      Yes
# 1        No  Research & Development    Male         2           5130       No
# 2       Yes  Research & Development    Male         1           2090      Yes
# 3        No  Research & Development  Female         1           2909      Yes
# 4        No  Research & Development    Male         1           3468       No
#
#    TrainingTimesLastYear  YearsAtCompany  YearsInCurrentRole  \
# 0                      0               6                   4
# 1                      3              10                   7
# 2                      3               0                   0
# 3                      3               8                   7
# 4                      3               2                   2
#
#    YearsSinceLastPromotion Education_text JobInvolvement_text  \
# 0                        0        College                High
# ...

# %%
#sarakkeiden uudelleenjärjestys

df = df[['Age Class', 'Attrition', 'DailyRateClass', 'Department', 'Distance Class', 
         'Education_text', 'Gender', 'JobInvolvement_text', 'JobLevel', 
         'MonthlyIncome', 'Overall Satisfaction', 'OverTime', 'PerformanceRating_text',
         'RelationshipSatisfaction_text', 'TrainingTimesLastYear', 'YearsAtCompany', 'YearsInCurrentRole', 
         'YearsSinceLastPromotion', 'WorkLifeBalance_text']]
df.head()
# Out:
#   Age Class Attrition DailyRateClass              Department Distance Class  \
# 0  (40, 50]       Yes   (1000, 1250]                   Sales         (0, 5]
# 1  (40, 50]        No     (250, 500]  Research & Development        (5, 10]
# 2  (30, 40]       Yes   (1250, 1500]  Research & Development         (0, 5]
# 3  (30, 40]        No   (1250, 1500]  Research & Development         (0, 5]
# 4  (20, 30]        No     (500, 750]  Research & Development         (0, 5]
#
#   Education_text  Gender JobInvolvement_text  JobLevel  MonthlyIncome  \
# 0        College  Female                High         2           5993
# 1  Below College    Male              Medium         2           5130
# 2        College    Male              Medium         1           2090
# 3         Master  Female                High         1           2909
# 4  Below College    Male                High         1           3468
#
#    Overall Satisfaction OverTime PerformanceRating_text  \
# ...

# %%
df[df['Overall Satisfaction']>=3.5]
# Out:
#      Age Class Attrition    DailyRateClass              Department  \
# 5     (30, 40]        No  (1000.0, 1250.0]  Research & Development
# 11    (20, 30]        No               NaN  Research & Development
# 19    (30, 40]        No    (250.0, 500.0]  Research & Development
# 23    (20, 30]        No    (250.0, 500.0]  Research & Development
# 30    (30, 40]        No   (750.0, 1000.0]  Research & Development
# 31    (40, 50]        No  (1250.0, 1500.0]  Research & Development
# 33    (30, 40]       Yes   (750.0, 1000.0]                   Sales
# 35    (40, 50]        No  (1250.0, 1500.0]  Research & Development
# 43    (20, 30]        No   (750.0, 1000.0]                   Sales
# 44    (20, 30]        No    (500.0, 750.0]  Research & Development
# 49    (30, 40]        No  (1000.0, 1250.0]  Research & Development
# 58    (30, 40]        No    (500.0, 750.0]  Research & Development
# 61    (30, 40]        No    (500.0, 750.0]  Research & Development
# ...

# %%
df[df['MonthlyIncome']>2400]
# Out:
#      Age Class Attrition    DailyRateClass              Department  \
# 0     (40, 50]       Yes  (1000.0, 1250.0]                   Sales
# 1     (40, 50]        No    (250.0, 500.0]  Research & Development
# 3     (30, 40]        No  (1250.0, 1500.0]  Research & Development
# 4     (20, 30]        No    (500.0, 750.0]  Research & Development
# 5     (30, 40]        No  (1000.0, 1250.0]  Research & Development
# 6     (50, 60]        No  (1250.0, 1500.0]  Research & Development
# 7     (20, 30]        No  (1250.0, 1500.0]  Research & Development
# 8     (30, 40]        No               NaN  Research & Development
# 9     (30, 40]        No  (1250.0, 1500.0]  Research & Development
# 10    (30, 40]        No   (750.0, 1000.0]  Research & Development
# 11    (20, 30]        No               NaN  Research & Development
# 12    (30, 40]        No    (500.0, 750.0]  Research & Development
# 13    (30, 40]        No  (1250.0, 1500.0]  Research & Development
# ...

# %%
df.to_excel('valmisteltu512.xlsx')
