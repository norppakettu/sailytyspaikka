# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('seaborn-darkgrid')

from matplotlib.ticker import MultipleLocator
from matplotlib.dates import DateFormatter

myLoc = MultipleLocator(14)

myFmt = DateFormatter('%Y/%m')

# %%
df=pd.read_csv('http://taanila.fi/beer.csv')
df.index=pd.to_datetime(df['Month'])
df=df.drop('Month',axis=1)
df.head()
# Out:
#             Monthly beer production
# Month
# 1956-01-01                     93.2
# 1956-02-01                     96.0
# 1956-03-01                     95.2
# 1956-04-01                     77.1
# 1956-05-01                     70.9

# %%
df.plot()

# %%
from statsmodels.tsa.api import seasonal_decompose

seasonal_decompose(df['Monthly beer production']['1984':]).plot()

# %%
from statsmodels.tsa.api import ExponentialSmoothing

malli = ExponentialSmoothing(df['Monthly beer production']).fit()
# Out:
# C:\Users\noora\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
df['Estimate'] = malli.fittedvalues
df.head(20)
# Out:
#             Monthly beer production    Estimate
# Month
# 1956-01-01                     93.2   93.203435
# 1956-02-01                     96.0   93.201107
# 1956-03-01                     95.2   95.097960
# 1956-04-01                     77.1   95.167114
# 1956-05-01                     70.9   82.922754
# 1956-06-01                     64.8   74.774749
# 1956-07-01                     70.1   68.014709
# 1956-08-01                     77.3   69.427943
# 1956-09-01                     79.5   74.762957
# 1956-10-01                    100.6   77.973323
# 1956-11-01                    100.7   93.307769
# 1956-12-01                    107.1   98.317597
# 1957-01-01                     95.9  104.269566
# 1957-02-01                     82.8   98.597383
# 1957-03-01                     83.3   87.891254
# 1957-04-01                     80.0   84.779691
# 1957-05-01                     80.4   81.540421
# 1957-06-01                     67.5   80.767540
# 1957-07-01                     75.7   71.775925
# 1957-08-01                     71.1   74.435331

# %%
df['1990':].plot()

# %%
df['Estimate error'] = malli.resid
df.tail(20)
# Out:
#             Monthly beer production    Estimate  Estimate error
# Month
# 1994-01-01                    151.0  178.707359      -27.707359
# 1994-02-01                    134.0  159.929657      -25.929657
# 1994-03-01                    164.0  142.356731       21.643269
# 1994-04-01                    126.0  157.024706      -31.024706
# 1994-05-01                    131.0  135.998787       -4.998787
# 1994-06-01                    125.0  132.611033       -7.611033
# 1994-07-01                    127.0  127.452919       -0.452919
# 1994-08-01                    143.0  127.145969       15.854031
# 1994-09-01                    143.0  137.890489        5.109511
# 1994-10-01                    160.0  141.353283       18.646717
# 1994-11-01                    190.0  153.990449       36.009551
# 1994-12-01                    182.0  178.394674        3.605326
# 1995-01-01                    138.0  180.838059      -42.838059
# 1995-02-01                    136.0  151.806050      -15.806050
# 1995-03-01                    152.0  141.094048       10.905952
# 1995-04-01                    127.0  148.485179      -21.485179
# 1995-05-01                    151.0  133.924344       17.075656
# 1995-06-01                    130.0  145.496778      -15.496778
# 1995-07-01                    119.0  134.994374      -15.994374
# 1995-08-01                    153.0  124.154742       28.845258

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

print('mean squared error', mean_squared_error(df['Monthly beer production']
                                               , df['Estimate']))
print('mean absolute error', mean_absolute_error(df['Monthly beer production'],
                                                 df['Estimate']))
# Out:
# mean squared error 356.770219307242
# mean absolute error 14.934240842075576

# %%
df['Estimate error']['1990':].plot()
plt.ylabel('Estimate error')
# Out:
# Text(0, 0.5, 'Estimate error')

# %%
plt.scatter(x = df['Estimate']['1990':], y = df['Monthly beer production']['1990':])
plt.xlabel('Estimate')
plt.ylabel('Monthly beer production')
# Out:
# Text(0, 0.5, 'Monthly beer production')

# %%
index = pd.date_range('1995-09-01', periods = 12, freq = 'MS')

ennusteet = malli.forecast(12)

df_ennuste = pd.DataFrame(data = ennusteet, index = index,
                         columns = ['Estimate'])

df_ennuste
# Out:
#               Estimate
# 1995-09-01  143.703615
# 1995-10-01  143.703615
# 1995-11-01  143.703615
# 1995-12-01  143.703615
# 1996-01-01  143.703615
# 1996-02-01  143.703615
# 1996-03-01  143.703615
# 1996-04-01  143.703615
# 1996-05-01  143.703615
# 1996-06-01  143.703615
# 1996-07-01  143.703615
# 1996-08-01  143.703615

# %%
df['Monthly beer production']['1990':].plot()

df_ennuste['Estimate']['1990':].plot()

# %%
df = pd.concat([df, df_ennuste])
df
# Out:
# C:\Users\noora\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#               Estimate  Estimate error  Monthly beer production
# 1956-01-01   93.203435       -0.003435                     93.2
# 1956-02-01   93.201107        2.798893                     96.0
# 1956-03-01   95.097960        0.102040                     95.2
# 1956-04-01   95.167114      -18.067114                     77.1
# 1956-05-01   82.922754      -12.022754                     70.9
# 1956-06-01   74.774749       -9.974749                     64.8
# 1956-07-01   68.014709        2.085291                     70.1
# 1956-08-01   69.427943        7.872057                     77.3
# 1956-09-01   74.762957        4.737043                     79.5
# 1956-10-01   77.973323       22.626677                    100.6
# 1956-11-01   93.307769        7.392231                    100.7
# 1956-12-01   98.317597        8.782403                    107.1
# 1957-01-01  104.269566       -8.369566                     95.9
# 1957-02-01   98.597383      -15.797383                     82.8
# 1957-03-01   87.891254       -4.591254                     83.3
# 1957-04-01   84.779691       -4.779691                     80.0
# 1957-05-01   81.540421       -1.140421                     80.4
# 1957-06-01   80.767540      -13.267540                     67.5
# 1957-07-01   71.775925        3.924075                     75.7
# 1957-08-01   74.435331       -3.335331                     71.1
# 1957-09-01   72.174926       17.125074                     89.3
# 1957-10-01   83.780851       17.319149                    101.1
# 1957-11-01   95.518304        9.681696                    105.2
# 1957-12-01  102.079738       12.020262                    114.1
# 1958-01-01  110.226054      -13.926054                     96.3
# 1958-02-01  100.788154      -16.388154                     84.4
# 1958-03-01   89.681651        1.518349                     91.2
# 1958-04-01   90.710659       -8.810659                     81.9
# 1958-05-01   84.739540       -4.239540                     80.5
# 1958-06-01   81.866339      -11.466339                     70.4
# ...                ...             ...                      ...
# 1994-03-01  142.356731       21.643269                    164.0
# 1994-04-01  157.024706      -31.024706                    126.0
# 1994-05-01  135.998787       -4.998787                    131.0
# 1994-06-01  132.611033       -7.611033                    125.0
# 1994-07-01  127.452919       -0.452919                    127.0
# 1994-08-01  127.145969       15.854031                    143.0
# 1994-09-01  137.890489        5.109511                    143.0
# 1994-10-01  141.353283       18.646717                    160.0
# 1994-11-01  153.990449       36.009551                    190.0
# 1994-12-01  178.394674        3.605326                    182.0
# 1995-01-01  180.838059      -42.838059                    138.0
# 1995-02-01  151.806050      -15.806050                    136.0
# 1995-03-01  141.094048       10.905952                    152.0
# 1995-04-01  148.485179      -21.485179                    127.0
# 1995-05-01  133.924344       17.075656                    151.0
# 1995-06-01  145.496778      -15.496778                    130.0
# 1995-07-01  134.994374      -15.994374                    119.0
# 1995-08-01  124.154742       28.845258                    153.0
# 1995-09-01  143.703615             NaN                      NaN
# 1995-10-01  143.703615             NaN                      NaN
# 1995-11-01  143.703615             NaN                      NaN
# 1995-12-01  143.703615             NaN                      NaN
# 1996-01-01  143.703615             NaN                      NaN
# 1996-02-01  143.703615             NaN                      NaN
# 1996-03-01  143.703615             NaN                      NaN
# 1996-04-01  143.703615             NaN                      NaN
# 1996-05-01  143.703615             NaN                      NaN
# 1996-06-01  143.703615             NaN                      NaN
# 1996-07-01  143.703615             NaN                      NaN
# 1996-08-01  143.703615             NaN                      NaN
#
# [488 rows x 3 columns]

# %%
malli.params
# Out:
# {'smoothing_level': 0.677715325172122,
#  'smoothing_slope': nan,
#  'smoothing_seasonal': nan,
#  'damping_slope': nan,
#  'initial_level': 93.20343476228899,
#  'initial_slope': nan,
#  'initial_seasons': array([], dtype=float64),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}
